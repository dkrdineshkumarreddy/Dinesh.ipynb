# %% [markdown]
# <a href="https://colab.research.google.com/github/dkrdineshkumarreddy/Dinesh.ipynb/blob/main/if_conditions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
customer_amount=5000
user_pin=int(input("Enter user_pin is : "))
if user_pin==1122:
    withdraw=float(input("Enter withdraw money : "))
    balance=customer_amount-withdraw
    print("updated_balnce is : ",balance)
else:
    print("please check  pin number")
# Out:
# Enter user_pin is : 1122
# Enter withdraw money : 3000
# updated_balnce is :  2000.0

# %%
number=int(input("Enter number : "))
if number>=1 and number<=3:
    if number==1:
        print("One")
    elif number==2:
        print("Two")
    else:
         print("Three")
else:
     print("Invalid number")

# %%
units=int(input("Enter number of units : "))
if units<=100:
    price=1.5
elif units<=200:
     price=2.5
elif units<=300:
      price=4
else:
      price=6
total_bill=units*price
print("Total_bill is : ",total_bill)
# Out:
# Enter number of units : 400
# Total_bill is :  2400

# %%
temperature=int(input("Enter temperature : "))
if temperature>35:
    print("Its's too hot,Stay indoors.")
elif temperature>25:
    print("Nice Weather,go Out!")
elif temperature>15:
     print("Cool Weather,Wear jacket.")
else:
     print("Too Cold,Stay Warm.")
# Out:
# Enter temperature : 26
# Nice Weather,go Out!

# %%
temperature=int(input("Enter temperature : "))
cough =input("Enter cough status : ")
Tiredness=input("Enter Tiredness status : ")
if temperature>99:
    print("You have Fever")
else:
    print("you have No Fever ")
if cough=="yes":
    print("You might have a cold")
else:
    print("you have no cold")
if Tiredness=="yes":
    print("Take Somerest.")
else:
    print("No need to rest.")
# Out:
# Enter temperature : 99
# Enter cough status : no
# Enter Tiredness status : no
# you have No Fever
# you have no cold
# No need to rest.

# %%
Age=int(input("Enter Age : "))
qualification=input("Enter qualification : ")
experience=int(input("Enter experience : "))
if Age>=18:
    print("Eligible")
else:
    print("Not Eligible")

if qualification=="graduate":
    print("Eligible")
else:
     print("Not Eligible")
if experience>=2:
     print("Preferred")
else:
     print("Not Preferred")
# Out:
# Enter Age : 20
# Enter qualification : graduate
# Enter experience : 2
# Eligible
# Eligible
# Preferred

# %%
income=float(input("Enter income : "))
if income>25000:
    credit_score=int(input("Enter credit : "))
    if credit_score>700:
        print("Eligible")
    else:
         print("Improve your credit score.")
else:
     print("Income too low for loan.")

# %%
Age=int(input("Enter age : "))
if Age<18:
    print("Not Eligible.")
elif Age>=18 and Age<=60:
     vision=input("Enter vision : ")
     test=input("Enter test : ")
     if vision=="good" and test=="passed":
        print("License Approved.")
     else:
          print("Fail in test or vision check.")
else:
    print("Senior citizen---medical check required.")
# Out:
# Enter age : 19
# Enter vision : good
# Enter test : passed
# License Approved.

# %%
print("Welcome to Keka Hotel")
print("1.Idly  - 50")
print("2.Dosa  - 100")
print("3.Vada  - 150")
print("4.Puri  - 120")
choice=int(input("Enter your choice : "))
if choice>=1 and choice<=4:
    if choice==1:
        item="Idly"
        cost=50
        print("Item name : Idly")
        print("cost is : 50")
    elif choice==2:
          item="Dosa"
          cost=100
          print("Item name : Dosa")
          print("cost is : 100")
    elif choice==3:
          item="Vada"
          cost=150
          print("Item name : Vada")
          print("cost is : 150")
    else:
          item="Puri"
          cost=120
          print("Item name : Puri")
          print("cost is : 120")
    qty=int(input("Enter qty is : "))
    bill=qty*cost
    print("Bill_amount is : ",bill)
else:
     print("Invalid selection")
# Out:
# Welcome to Keka Hotel
# 1.Idly  - 50
# 2.Dosa  - 100
# 3.Vada  - 150
# 4.Puri  - 120
# Enter your choice : 3
# Item name : Vada
# cost is : 150
# Enter qty is : 6
# Bill_amount is :  900

# %%
print("Welcome to Keka Hotel")
print("1.Idly  - 50")
print("2.Dosa  - 100")
print("3.Vada  - 150")
print("4.Puri  - 120")
choice=int(input("Enter your choice : "))
if choice>=1 and choice<=4:
    if choice==1:
        item="Idly"
        cost=50
        print("Idly cost is : ",cost)
    elif choice==2:
          item="Dosa"
          cost=100
          print("Dosa cost is : ",cost)
    elif choice==3:
          item="Vada"
          cost=150
          print("Vada cost is : ",cost)

    else:
          item="Puri"
          cost=120
          print("Puri cost is : ",cost)

    qty=int(input("Enter qty is : "))
    bill=qty*cost
    print("Bill_amount is : ",bill)
    discount=int(input("Discount is : "))
    discount_amt=bill*discount/100
    print("Discount Amt : ",discount_amt)
    final_bill=bill-discount_amt
    print("Final Bill is : ",final_bill)
    paid_amt=float(input(" Paid Amt : "))
    Balance=paid_amt-final_bill
    print("Balance is : ",Balance)

else:
     print("Invalid selection")
# Out:
# Welcome to Keka Hotel
# 1.Idly  - 50
# 2.Dosa  - 100
# 3.Vada  - 150
# 4.Puri  - 120
# Enter your choice : 3
# Vada cost is :  150
# Enter qty is : 6
# Bill_amount is :  900
# Discount is : 20
# Discount Amt :  180.0
# Final Bill is :  720.0
#  Paid Amt : 1000
# Balance is :  280.0

# %%
print("Welcome to Keka Hotel")
print("1.Idly  - 50")
print("2.Dosa  - 100")
print("3.Vada  - 150")
print("4.Puri  - 120")
choice=int(input("Enter your choice : "))
if choice>=1 and choice<=4:
    if choice==1:
        item="Idly"
        cost=50
        print("Idly cost is : ",cost)
    elif choice==2:
          item="Dosa"
          cost=100
          print("Dosa cost is : ",cost)
    elif choice==3:
          item="Vada"
          cost=150
          print("Vada cost is : ",cost)

    else:
          item="Puri"
          cost=120
          print("Puri cost is : ",cost)

    qty=int(input("Enter qty is : "))
    bill=qty*cost
    print("Bill_amount is : ",bill)
    discount=int(input("Discount is : "))
    discount_amt=bill*discount/100
    print("Discount Amt : ",discount_amt)
    final_bill=bill-discount_amt
    print("Final Bill is : ",final_bill)
    paid_amt=float(input(" Paid Amt : "))
    Balance=paid_amt-final_bill
    print("Balance is : ",Balance)

else:
     print("Sorry...! No Matching Found.")
# Out:
# Welcome to Keka Hotel
# 1.Idly  - 50
# 2.Dosa  - 100
# 3.Vada  - 150
# 4.Puri  - 120
# Enter your choice : 4
# Puri cost is :  120
# Enter qty is : 2
# Bill_amount is :  240
# Discount is : 0
# Discount Amt :  0.0
# Final Bill is :  240.0
#  Paid Amt : 500
# Balance is :  260.0

# %%
print("Welcome to Keka Hotel.")
print(" 1.Idly --- 50")
print(" 2.Dosa     ")
print("       1.Plain  Dosa ---- 100")
print("       2.Onion  Dosa ---- 150")
print("       3.Masala Dosa ---- 200")
print(" 3.Vada --- 100")
print(" 4.Puri --- 150")
choice=int(input("Enter your choice : "))
if choice>=1 and choice<=4:
    if choice==1:
        item="Idly"
        cost=50
        print("Idly cost is : ",cost)
    elif choice==2:
         item="Dosa"
         print("Dosa")
         choice=int(input("Enter Dosa choice : "))
         if choice>=1 and choice<=3:
            if choice==1:
                item ="Plain Dosa"
                cost=100
                print("Plain Dosa cost is : ",cost)
            elif choice==2:
                 item= "Onion Dosa"
                 cost=150
                 print("Onion Dosa is : ",cost)
            else:
                 item="Masala Dosa"
                 cost=200
                 print("Masala Dosa is : ",cost)
    elif choice==3:
         item="Vada"
         cost=100
         print("Vada cost is : ",cost)
    else:
         item="Puri"
         cost=150
         print("Puri cost is : ",cost)
    qty=int(input("Enter Quantity : "))
    bill_amt=qty*cost
    print("Bill_Amt : ",bill_amt)
    if bill_amt>=500:
       discount=20
       discount_amt=bill_amt*discount/100
       print("Discount_Amt is : ",discount_amt)
       final_bill=bill_amt-discount_amt
       print("Final_bill is : ",final_bill)
       paid_amt=float(input("Enter paid_amt : "))
       Balance=paid_amt-final_bill
       print("Balance_Amt is : ",Balance)
else:
      print("Sorry...! your choice not Available.")
# Out:
# Welcome to Keka Hotel.
#  1.Idly --- 50
#  2.Dosa
#        1.Plain  Dosa ---- 100
#        2.Onion  Dosa ---- 150
#        3.Masala Dosa ---- 200
#  3.Vada --- 100
#  4.Puri --- 150
# Enter your choice : 4
# Puri cost is :  150
# Enter Quantity : 2
# Bill_Amt :  300
